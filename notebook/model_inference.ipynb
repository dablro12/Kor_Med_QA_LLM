# %%
import sys 
sys.path.append("/workspace/")

# %%
import sys 
sys.path.append("/workspace/")
import pandas as pd 
from src.qa_prompt import get_snuh_ClinicalQA_prompt
df = pd.read_csv("/workspace/kor_med_opendataset/snuh_ClinicalQA/train.csv")
row_sample = df.head(5).to_dict(orient="records")[0]
gt_answer = row_sample['answer']
gt_explanation = row_sample['explanation']
qa_prompt = get_snuh_ClinicalQA_prompt(row_sample)
print(qa_prompt)

# %% [markdown]
# # Model Series

# %% [markdown]
# ## gpt-oss-20b

# %%
from src.gpt import GPT

model = GPT(hg_model_id = "gpt-oss-20b", cache_dir="/workspace/kor_med_opendataset/hg_cache")

model.run("Explain quantum mechanics clearly and concisely.")

# %% [markdown]
# ## Meta

# %% [markdown]
# ### Llama-3.1-8B-Instruct

# %%
import sys 
sys.path.append("/workspace/")
import pandas as pd 
from src.qa_prompt import get_snuh_ClinicalQA_prompt
df = pd.read_csv("/workspace/kor_med_opendataset/snuh_ClinicalQA/train.csv")
row_sample = df.head(5).to_dict(orient="records")[3]
gt_answer = row_sample['answer']
gt_explanation = row_sample['explanation']
qa_prompt = get_snuh_ClinicalQA_prompt(row_sample)

# %%
from src.llama import Llama
model = Llama(
    hg_model_id="meta-llama/Llama-3.2-1B-Instruct",
    device="cuda",
    cache_dir="/workspace/kor_med_opendataset/hg_cache"
)
response = model.run(qa_prompt, max_new_tokens=512)
print("Response:", response)
from snuh_ClinicalQA_benchmark import parse_model_response
print("------parse_model_response------")
print(parse_model_response(response))

# %% [markdown]
# ## Qwen

# %% [markdown]
# ### Qwen/Qwen3-4B-Instruct-2507

# %%
import sys 
sys.path.append("/workspace/")
import pandas as pd 
from src.qa_prompt import get_snuh_ClinicalQA_prompt
df = pd.read_csv("/workspace/kor_med_opendataset/snuh_ClinicalQA/train.csv")
row_sample = df.head(1).to_dict(orient="records")[0]
gt_answer = row_sample['answer']
gt_explanation = row_sample['explanation']
qa_prompt = get_snuh_ClinicalQA_prompt(row_sample)

# %%
from src.qwen import Qwen
# model = Qwen(hg_model_id="Qwen/Qwen3-4B-Instruct-2507", device="cuda", cache_dir="/workspace/kor_med_opendataset/hg_cache")
model = Qwen(hg_model_id="Qwen/Qwen3-8B", device="cuda", cache_dir="/workspace/kor_med_opendataset/hg_cache")
response = model.run(qa_prompt, max_new_tokens=512, temperature=0.1, top_p=0.9)
print("Response:", response)
from snuh_ClinicalQA_benchmark import parse_model_response
print("------parse_model_response------")
print(parse_model_response(response))

# %% [markdown]
# ## Gemma

# %% [markdown]
# ### google/gemma-3-4b-it

# %%
import sys 
sys.path.append("/workspace/")
import pandas as pd 
from src.qa_prompt import get_snuh_ClinicalQA_prompt
df = pd.read_csv("/workspace/kor_med_opendataset/snuh_ClinicalQA/train.csv")
row_sample = df.head(5).to_dict(orient="records")[3]
gt_answer = row_sample['answer']
gt_explanation = row_sample['explanation']
qa_prompt = get_snuh_ClinicalQA_prompt(row_sample)

# %%
from src.gemma import Gemma
model = Gemma(
    hg_model_id="google/gemma-3-4b-it",
    device="cuda",
    cache_dir="/workspace/kor_med_opendataset/hg_cache"
)

response = model.run(qa_prompt, max_new_tokens=512)
print("Response:", response)
from snuh_ClinicalQA_benchmark import parse_model_response
print("------parse_model_response------")
print(parse_model_response(response))

# %% [markdown]
# ## Exaone

# %% [markdown]
# ### LGAI-EXAONE/EXAONE-3.5-2.4B-Instruct

# %%
import sys 
sys.path.append("/workspace/")
import pandas as pd 
from src.qa_prompt import get_snuh_ClinicalQA_prompt
df = pd.read_csv("/workspace/kor_med_opendataset/snuh_ClinicalQA/train.csv")
row_sample = df.head(5).to_dict(orient="records")[3]
gt_answer = row_sample['answer']
gt_explanation = row_sample['explanation']
qa_prompt = get_snuh_ClinicalQA_prompt(row_sample)

# cuda : 0만 사용
import os 
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

from src.exaone import Exaone
model = Exaone(
    hg_model_id="LGAI-EXAONE/EXAONE-4.0-1.2B",
    device="cuda",
    cache_dir="/workspace/kor_med_opendataset/hg_cache"
)

response = model.run(qa_prompt, max_new_tokens=512)
print("Response:", response)
from snuh_ClinicalQA_benchmark import parse_model_response
print("------parse_model_response------")
print(parse_model_response(response))

# %% [markdown]
# ## Kakao

# %% [markdown]
# ### kakaocorp/kanana-1.5-v-3b-instruct

# %%
import sys 
sys.path.append("/workspace/")
import pandas as pd 
from src.qa_prompt import get_snuh_ClinicalQA_prompt
df = pd.read_csv("/workspace/kor_med_opendataset/snuh_ClinicalQA/train.csv")
row_sample = df.head(5).to_dict(orient="records")[3]
gt_answer = row_sample['answer']
gt_explanation = row_sample['explanation']
qa_prompt = get_snuh_ClinicalQA_prompt(row_sample)

# cuda : 0만 사용
import os 
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
from src.kanana import Kanana
model = Kanana(
    hg_model_id="kakaocorp/kanana-1.5-2.1b-instruct-2505",
    device="cuda",
    cache_dir="/workspace/kor_med_opendataset/hg_cache"
)

response = model.run(qa_prompt, max_new_tokens=512)
print("Response:", response)
from snuh_ClinicalQA_benchmark import parse_model_response
print("------parse_model_response------")
print(parse_model_response(response))
# Out:
# /opt/conda/lib/python3.11/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# [Kanana] cache_dir = /workspace/kor_med_opendataset/hg_cache
# [Kanana] model cache dir = /workspace/kor_med_opendataset/hg_cache/models--kakaocorp--kanana-1.5-2.1b-instruct-2505
# [Kanana] local_files_only = True
# `torch_dtype` is deprecated! Use `dtype` instead!
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# ...
